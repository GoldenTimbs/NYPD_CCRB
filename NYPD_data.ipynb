# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\Danny\\Desktop\\ttpclass\\allegations_2020.csv')

# %%
df
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
df['complainant_ethnicity'].fillna("Unknown", inplace = True)
df['complainant_gender'].fillna("Unknown", inplace = True)

# %%
df
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
df.to_csv('allegations2_2020.csv', encoding='utf-8')

# %%
mask = df['allegation']=='Interference with recording'

df[mask]

# %%
df.groupby('allegation')['complainant_ethnicity'].size()
# Out:
# allegation
# Action               316
# Animal                 3
# Arrest/D. A. T.        6
# Arrest/Onlooker        4
# Beat                  57
#                     ...
# Vehicle Searched      22
# Vehicle search      1405
# Vehicle stop        1094
# White                  8
# Word                3942
# Name: complainant_ethnicity, Length: 115, dtype: int64

# %%
df.groupby('precinct')[['allegation','board_disposition']].size()
# Out:
# precinct
# 0.0        21
# 1.0       174
# 5.0       160
# 6.0       175
# 7.0       221
#          ...
# 120.0     844
# 121.0     366
# 122.0     238
# 123.0     112
# 1000.0      3
# Length: 79, dtype: int64

# %%
df.groupby(['complainant_ethnicity','complainant_gender']).agg(np.mean)['complainant_age_incident'].round()
# Out:
# complainant_ethnicity  complainant_gender
# American Indian        Female                   39.0
#                        Male                     31.0
# Asian                  Female                   37.0
#                        Male                     34.0
# Black                  Female                   35.0
#                        Gender non-conforming    35.0
#                        Male                     32.0
#                        Not described            31.0
#                        Transman (FTM)           44.0
#                        Transwoman (MTF)         41.0
# Hispanic               Female                   34.0
#                        Male                     31.0
#                        Not described            30.0
#                        Transwoman (MTF)         36.0
# Other Race             Female                   37.0
#                        Male                     31.0
#                        Not described            50.0
# ...

# %%
officer_misc = df.groupby(['fado_type','allegation'])['unique_mos_id']

# %%
officer_misc.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7c9c61ac8462> in <module>
# ----> 1 officer_misc.to_frame()
#
# ~\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     579
#     580         raise AttributeError(
# --> 581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#     583
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'to_frame'

# %%
comp_demo = df.groupby('complainant_gender',)[['complainant_ethnicity', 'complainant_age_incident']]

# %%
comp_demo.get_group('Female').agg(np.mean).round(2)
# Out:
# complainant_age_incident    36.0
# dtype: float64

# %%
comp_demo.get_group('Male').agg(np.mean).round(2)
# Out:
# complainant_age_incident    31.75
# dtype: float64

# %%
ab = df.groupby('complainant_ethnicity')

# %%
comp_demo.size()
# Out:
# complainant_gender
# Female                    5021
# Gender non-conforming        2
# Male                     24058
# Not described               57
# Transman (FTM)               5
# Transwoman (MTF)            20
# dtype: int64

# %%
b = df.groupby('complainant_gender')['command_at_incident']

# %%
b.count()
# Out:
# complainant_gender
# Female                    4996
# Gender non-conforming        2
# Male                     23941
# Not described               57
# Transman (FTM)               5
# Transwoman (MTF)            20
# Name: command_at_incident, dtype: int64

# %%
df
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
df.groupby('precinct')[['fado_type', 'allegation']]

# %%
df['complainant_ethnicity'].values
# Out:
# array(['Black', 'Black', 'Black', ..., 'Asian', 'Asian', 'Asian'],
#       dtype=object)
